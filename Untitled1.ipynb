# %%
# Import the core libraries for numerical work (NumPy), data handling (pandas), and plotting (Matplotlib/Seaborn).

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the schedule feature dataset from a local Parquet file into a pandas DataFrame.

df = pd.read_parquet("schedule_features_2016_2025.parquet")

# %%
df.tail(1).T
# Out:
#                               2760
# game_id             2025_22_SEA_NE
# season                        2025
# game_type                       SB
# week                            22
# away_team                      SEA
# away_score                     NaN
# home_team                       NE
# home_score                     NaN
# result                         NaN
# total                          NaN
# overtime                       NaN
# away_rest                       14
# home_rest                       14
# div_game                         0
# roof                      outdoors
# surface                      grass
# r_away                 1748.746739
# r_home                 1665.011062
# off_epa_pp_away           0.109102
# off_epa_pp_home          -0.022864
# def_epa_pp_away           -0.12881
# def_epa_pp_home          -0.266123
# turnover_rate_away        0.006251
# turnover_rate_home        0.008233
